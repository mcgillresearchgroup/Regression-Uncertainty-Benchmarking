# %%
import ucimlrepo
import numpy as np
import pandas as pd
import time

# %%
dataset = ucimlrepo.fetch_ucirepo(id=374)
data_x = dataset.data.features
data_y = dataset.data.targets
datetime = data_x['date']
data_x = data_x.drop(columns=['date'])
dt_cleaned = []
for i in range(len(datetime)):
    dt_split_1 = datetime[i][:10] + '-' + datetime[i][11:]
    dt_split_2 = dt_split_1.split('-')
    dt_split_3 = dt_split_2[:-1] + dt_split_2[-1].split(':')
    dt_cleaned.append(dt_split_3)
    years = int(dt_split_3[0])
    months = int(dt_split_3[1])
    days = int(dt_split_3[2])
    hours = int(dt_split_3[3])
    minutes = int(dt_split_3[4])
    seconds = int(dt_split_3[5])
print(dt_cleaned)
# Out:
# 0        2016-01-1117:00:00
# 1        2016-01-1117:10:00
# 2        2016-01-1117:20:00
# 3        2016-01-1117:30:00
# 4        2016-01-1117:40:00
#                 ...
# 19730    2016-05-2717:20:00
# 19731    2016-05-2717:30:00
# 19732    2016-05-2717:40:00
# 19733    2016-05-2717:50:00
# 19734    2016-05-2718:00:00
# Name: date, Length: 19735, dtype: str
# ...
